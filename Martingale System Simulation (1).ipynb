# %%
# Import libraries
import pandas as pd
import numpy as np
import random
import math

# %%
# Declare variables
# iterations (n)
n = 1_000_000

# winning odds (r), blackjack rate is 0.44
r = 0.44

# base bet (b)
b = 100

# table maximum (M)
m = 1000

# %%
# Calculate max consecutive losses before table max is hit (mcl)

def round_down(n, decimals=0):
    multiplier = 10 ** decimals
    return math.floor(n * multiplier) / multiplier

mcl = round_down(math.log(m/b,2))+2
print(mcl)
# Out:
# 5.0

# %%
# Generate win/loss array
win_loss_array = []
for i in range (0,n):
    win_loss_generation = random.choices([0,1], weights = [1-r,r])
    win_loss_number = win_loss_generation[0]
    if win_loss_number >= 0.5:
        win_loss_array += 'W'
    else:
        win_loss_array += 'L'

# Generate dummy array for the simulated data
consecutive_l = [None] * n
bet_amount = [None] * n
round_cashflow = [None] * n
max_bet_counter = [None] * n

# Print first 10 items of the resultant arrays
print('The first 10 items of the win/loss array:')
print(win_loss_array[:10])
# Out:
# The first 10 items of the win/loss array:
# ['L', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W']

# %%
# Generate base dataframe
df = pd.DataFrame({'W/L' : win_loss_array[:],
                   'Consecutive L': consecutive_l[:],
                   'Max Bet Counter': max_bet_counter[:],
                   'Bet Amount': bet_amount[:],
                   'Round Cashflow': round_cashflow[:],
                  })
print('The first 5 items of the resultant dataframe:')
display(df.head())
# Out:
# The first 5 items of the resultant dataframe:
#   W/L Consecutive L Max Bet Counter Bet Amount Round Cashflow
# 0   L          None            None       None           None
# 1   W          None            None       None           None
# 2   W          None            None       None           None
# 3   W          None            None       None           None
# 4   L          None            None       None           None

# %%
# Count consecutive L
if df.iloc[0,0] == 'W':
    df.iloc[0,1] = 0
else:
    df.iloc[0,1] = 1
    
for i in range(1,n):
    if df.iloc[i,0] == 'L':
        df.iloc[i,1] = df.iloc[i-1,1]+1
    else:
        df.iloc[i,1] = 0

# %%
# Generate max bet counter
df.iloc[0,2] = 0

for i in range(1,n):
    # Scenario 1: max bet counter is 0 and max consecutive loss is not reached
    if df.iloc[i,1] < mcl and df.iloc[i-1,2] == 0:
        df.iloc[i,2] = 0
    # Scenario 2: max bet counter is 0 and we lost the first max table bet
    elif df.iloc[i,1] == mcl and df.iloc[i-1,2] == 0 and df.iloc[i,0] == 'L':
        df.iloc[i,2] = 2
    # Scenario 3: max bet counter has started counting and we l lose
    elif df.iloc[i-1,2] > 0 and df.iloc[i,0] == 'L':
        df.iloc[i,2] = df.iloc[i-1,2]+1
    # Scenario 4: max bet counter has started counting and we win
    elif  df.iloc[i-1,2] > 0 and df.iloc[i,0] == 'W':
        df.iloc[i,2] = df.iloc[i-1,2]-1

# %%
# Generate bet amount

# Start initial bet (b)
df.iloc[0,3] = b

# Second bet is always (b) regardless of the outcome of the first round
df.iloc[1,3] = b

for i in range(2,n):
    # Scenario 1: max bet not hit, last 2 games were losses
    if df.iloc[i,2] == 0 and df.iloc[i-1,0] == 'L' and df.iloc[i-2,0] == 'L':
        df.iloc[i,3] = df.iloc[i-1,3]*2
    # Scenario 2: max bet not hit, won last game
    elif df.iloc[i,2] == 0 and df.iloc[i-1,0] == 'W':
        df.iloc[i,3] = b
    # Scenario 3: max bet not hit, previous round lost but the one before is win
    elif df.iloc[i,2] == 0 and df.iloc[i-1,0] == 'L' and df.iloc[i-2,0] == 'W':
        df.iloc[i,3] = b
    # Scenario 4: max bet hit, need to place max bet
    elif df.iloc[i,2] > 0:
        df.iloc[i,3] = (2**(mcl-2))*10

# %%
# Generate round cashflow
for i in range(0,n):
    if df.iloc[i,0] == 'L':
        df.iloc[i,4] = df.iloc[i,3]*-1
    else:
        df.iloc[i,4] = df.iloc[i,3]

# %%
# Generate total cashflow of previous rounds
df['Total Cashflow'] = df['Round Cashflow'].cumsum()

# %%
# check last 5 rows to check for simulation completion
df.iloc[-3:]
# Out:
#        W/L Consecutive L Max Bet Counter Bet Amount Round Cashflow  \
# 999997   L             1          120420       80.0          -80.0
# 999998   L             2          120421       80.0          -80.0
# 999999   L             3          120422       80.0          -80.0
#
#        Total Cashflow
# 999997     -9630620.0
# 999998     -9630700.0
# 999999     -9630780.0

# %%
# Summary statistics
print('Summary statistics: \n')

print("Total iterations ran: %s" % '{:,}'.format((n)))
print("Total wins: %s" % '{:,}'.format((df['W/L'].value_counts()['W'])))
print("Total losses: %s" % '{:,}'.format((df['W/L'].value_counts()['L'])))
print("Win rate: %s" % "{0:.02%}".format((df['W/L'].value_counts()['W'])/n))
print("Expected Win rate: %s \n" % "{0:.02%}".format(r))

print("Most consecutive losses in a row: %s" % '{:,}'.format(df['Consecutive L'].max()))
print("Lowest Round Cashflow: %s" % '{:,}'.format(df['Round Cashflow'].min()))
print("Lowest Total Cashflow: %s" % '{:,}'.format(df['Total Cashflow'].min()))
print("Final Total Cashflow: %s" % '{:,}'.format(df.iloc[-1,5]))
# Out:
# Summary statistics:
#
# Total iterations ran: 1,000,000
# Total wins: 439,786
# Total losses: 560,214
# Win rate: 43.98%
# Expected Win rate: 44.00%
#
# Most consecutive losses in a row: 23
# Lowest Round Cashflow: -400
# Lowest Total Cashflow: -9,630,860.0
# Final Total Cashflow: -9,630,780.0

# %%
# Generate full dataframe for sanity check
df.iloc[-50:]
# Out:
#        W/L Consecutive L Max Bet Counter Bet Amount Round Cashflow  \
# 999950   W             0          120419       80.0           80.0
# 999951   L             1          120420       80.0          -80.0
# 999952   W             0          120419       80.0           80.0
# 999953   L             1          120420       80.0          -80.0
# 999954   W             0          120419       80.0           80.0
# 999955   W             0          120418       80.0           80.0
# 999956   L             1          120419       80.0          -80.0
# 999957   L             2          120420       80.0          -80.0
# 999958   L             3          120421       80.0          -80.0
# 999959   L             4          120422       80.0          -80.0
# 999960   W             0          120421       80.0           80.0
# 999961   L             1          120422       80.0          -80.0
# 999962   W             0          120421       80.0           80.0
# 999963   L             1          120422       80.0          -80.0
# 999964   W             0          120421       80.0           80.0
# 999965   W             0          120420       80.0           80.0
# 999966   W             0          120419       80.0           80.0
# 999967   L             1          120420       80.0          -80.0
# 999968   W             0          120419       80.0           80.0
# 999969   L             1          120420       80.0          -80.0
# 999970   W             0          120419       80.0           80.0
# 999971   L             1          120420       80.0          -80.0
# 999972   L             2          120421       80.0          -80.0
# 999973   L             3          120422       80.0          -80.0
# 999974   W             0          120421       80.0           80.0
# 999975   W             0          120420       80.0           80.0
# 999976   W             0          120419       80.0           80.0
# 999977   L             1          120420       80.0          -80.0
# 999978   W             0          120419       80.0           80.0
# 999979   W             0          120418       80.0           80.0
# 999980   L             1          120419       80.0          -80.0
# 999981   L             2          120420       80.0          -80.0
# 999982   L             3          120421       80.0          -80.0
# 999983   L             4          120422       80.0          -80.0
# 999984   L             5          120423       80.0          -80.0
# 999985   W             0          120422       80.0           80.0
# 999986   L             1          120423       80.0          -80.0
# 999987   W             0          120422       80.0           80.0
# 999988   L             1          120423       80.0          -80.0
# 999989   W             0          120422       80.0           80.0
# 999990   L             1          120423       80.0          -80.0
# 999991   W             0          120422       80.0           80.0
# 999992   W             0          120421       80.0           80.0
# 999993   W             0          120420       80.0           80.0
# 999994   L             1          120421       80.0          -80.0
# 999995   W             0          120420       80.0           80.0
# 999996   W             0          120419       80.0           80.0
# 999997   L             1          120420       80.0          -80.0
# 999998   L             2          120421       80.0          -80.0
# 999999   L             3          120422       80.0          -80.0
#
#        Total Cashflow
# 999950     -9630540.0
# 999951     -9630620.0
# 999952     -9630540.0
# 999953     -9630620.0
# 999954     -9630540.0
# 999955     -9630460.0
# 999956     -9630540.0
# 999957     -9630620.0
# 999958     -9630700.0
# 999959     -9630780.0
# 999960     -9630700.0
# 999961     -9630780.0
# 999962     -9630700.0
# 999963     -9630780.0
# 999964     -9630700.0
# 999965     -9630620.0
# 999966     -9630540.0
# 999967     -9630620.0
# 999968     -9630540.0
# 999969     -9630620.0
# 999970     -9630540.0
# 999971     -9630620.0
# 999972     -9630700.0
# 999973     -9630780.0
# 999974     -9630700.0
# 999975     -9630620.0
# 999976     -9630540.0
# 999977     -9630620.0
# 999978     -9630540.0
# 999979     -9630460.0
# 999980     -9630540.0
# 999981     -9630620.0
# 999982     -9630700.0
# 999983     -9630780.0
# 999984     -9630860.0
# 999985     -9630780.0
# 999986     -9630860.0
# 999987     -9630780.0
# 999988     -9630860.0
# 999989     -9630780.0
# 999990     -9630860.0
# 999991     -9630780.0
# 999992     -9630700.0
# 999993     -9630620.0
# 999994     -9630700.0
# 999995     -9630620.0
# 999996     -9630540.0
# 999997     -9630620.0
# 999998     -9630700.0
# 999999     -9630780.0
